# %%
import pandas as pd
links= pd.read_csv("links.csv")
links.head(2)
# Out:
#    movieId  imdbId  tmdbId
# 0        1  114709   862.0
# 1        2  113497  8844.0

# %%
movies= pd.read_csv("movies.csv")
¸.head(2)
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy

# %%
movies[["title","genres"]].head(50)
# Out:
#                                                 title  \
# 0                                    Toy Story (1995)
# 1                                      Jumanji (1995)
# 2                             Grumpier Old Men (1995)
# 3                            Waiting to Exhale (1995)
# 4                  Father of the Bride Part II (1995)
# 5                                         Heat (1995)
# 6                                      Sabrina (1995)
# 7                                 Tom and Huck (1995)
# 8                                 Sudden Death (1995)
# 9                                    GoldenEye (1995)
# 10                     American President, The (1995)
# 11                 Dracula: Dead and Loving It (1995)
# 12                                       Balto (1995)
# 13                                       Nixon (1995)
# 14                            Cutthroat Island (1995)
# 15                                      Casino (1995)
# ...

# %%
ratings= pd.read_csv("ratings.csv")
ratings.head(2)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247

# %%
ratings.shape
# Out:
# (100836, 4)

# %%
ratings.userId.nunique()
# Out:
# 610

# %%
tags= pd.read_csv("tags.csv")
tags.head(2)
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996

# %%
tags.shape
# Out:
# (3683, 4)

# %%
tags.userId.nunique()
# Out:
# 58

# %%
ratings[ratings['userId'].isin(tags['userId'])].nunique()
# Out:
# userId          58
# movieId       6500
# rating          10
# timestamp    20803
# dtype: int64

# %%
grouped_df = ratings.groupby(by="userId").agg({'rating': ['sum', 'mean'], 'movieId': 'first' })

# %%
# Flatten MultiIndex columns
grouped_df.columns = [f'{col[0]}_{col[1]}' if col[1] != '' else col[0] for col in grouped_df.columns]

grouped_df.head(10)
# Out:
#         rating_sum  rating_mean  movieId_first
# userId
# 1           1013.0     4.366379              1
# 2            114.5     3.948276            318
# 3             95.0     2.435897             31
# 4            768.0     3.555556             21
# 5            160.0     3.636364              1
# 6           1097.0     3.493631              2
# 7            491.0     3.230263              1
# 8            168.0     3.574468              2
# 9            150.0     3.260870             41
# 10           459.0     3.278571            296

# %%
result = movies.merge(grouped_df, left_on='movieId', right_on="movieId_first", how='inner')

# %%
links
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
result2 = result.merge(links, right_on='movieId', left_on="movieId", how='inner')

# %%
result2.imdbId.unique()
# Out:
# array([114709, 113497, 113228, 114885, 113041, 113277, 114319, 114576,
#        113189, 112346, 112896, 112641, 114388, 113101, 112281, 113845,
#        113161, 112722, 114168, 113627, 114011, 112682, 112792, 114746,
#        112431, 112818, 112697, 114279, 113855, 114681, 114369, 114148,
#        114814, 110299, 110877, 113419, 113862, 115683, 113118, 116367,
#        113828, 112379, 115639, 115759, 115907, 116483, 117110, 112573,
#         75314, 109424, 116130, 112461, 112384, 112462,  61395, 112642,
#        109508, 112851, 113243, 113481, 113986, 114436, 114682, 112471,
#        112679, 109445, 109686, 110099,  76759, 110428, 110527, 110413,
#        110912, 111161, 114614, 108550, 109830, 110213, 111257, 109439,
#        108052, 108071, 108101,  83658, 110366, 103639, 102926, 117247,
#        116684, 118114, 116329,  55277,  78748,  74285, 117571, 132512,
#        154506])

# %%
import requests
import numpy as np
from bs4 import BeautifulSoup

def scrapper(imdbId):
    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0" * n_zeroes + id
    URL = f"https://www.imdb.com/title/tt{new_id}/"

    request_header = {
        'Content-Type': 'text/html; charset=UTF-8',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0',
        'Accept-Encoding': 'gzip, deflate, br'
    }

    response = requests.get(URL, headers=request_header)

    soup = BeautifulSoup(response.text, 'html.parser')

    imdb_rating = soup.find('span', attrs={'data-testid': 'hero-rating-bar__score'})

    return imdb_rating.text.strip() if imdb_rating else np.nan

# %%
links['result'] = links['imdbId'].apply(scrapper)

# %%
result[result['genres'].str.contains("Sci-Fi")==True ].sort_values(by="rating_sum").tail(100)
# Out:
#      movieId                                              title  \
# 401       29  City of Lost Children, The (Cité des enfants p...
# 388       24                                      Powder (1995)
# 556      260          Star Wars: Episode IV - A New Hope (1977)
# 595      541                                Blade Runner (1982)
# 544      172                             Johnny Mnemonic (1995)
# 560      260          Star Wars: Episode IV - A New Hope (1977)
# 559      260          Star Wars: Episode IV - A New Hope (1977)
# 564      260          Star Wars: Episode IV - A New Hope (1977)
# 410       32          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 584      327                                   Tank Girl (1995)
# 557      260          Star Wars: Episode IV - A New Hope (1977)
# 409       32          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 555      260          Star Wars: Episode IV - A New Hope (1977)
# 561      260          Star Wars: Episode IV - A New Hope (1977)
# ...

# %%
result.sort_values(by="rating_sum").tail(100)
# Out:
#      movieId             title                                       genres  \
# 177        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 104        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 296        6       Heat (1995)                        Action|Crime|Thriller
# 221        2    Jumanji (1995)                   Adventure|Children|Fantasy
# 119        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# ..       ...               ...                                          ...
# 214        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 154        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 204        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 164        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 146        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#      rating_sum  rating_mean  movieId_first
# ...
